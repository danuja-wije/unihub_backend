# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ------------------------------------ 232.6/232.6 kB 568.6 kB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=3.10.0.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from PyPDF2) (4.4.0)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import pandas as pd
import networkx as nx 
import spacy
import pandas as pd
from spacy import displacy
import PyPDF2

# %%
NER = spacy.load('en_core_web_sm')

# %%
path = 'Ambulance Booking System.pdf'

# %%
# Open the PDF file in read-only mode
with open(path, 'rb') as file:
    # Create a PDF object
    pdf = PyPDF2.PdfReader(file)

    # Get the number of pages in the PDF
    num_pages = len(pdf.pages)

    # Initialize an empty list to store the skills
    skills = []
    all_text = []
    # Iterate through each page of the PDF
    for i in range(num_pages):
        # Get the text of the current page
        page = pdf.pages[i]
        text = page.extract_text()
        all_text.append(text)
    print(" ".join(all_text))
# Out:
# Ambulance Booking System
# This system should be developed as a team. This team should be three or four members.
# Project specification
# In today’s traffic world, ambulance plays a significant role when an accident occurs on the road
# network, and the need arises to save valuable human life. Transportation of a patient to an
# emergency hospital seems quite simple, but in actuality, it is pretty tricky and gets more complex
# during peak hours.  Therefore, should create a web application to people can easily book  an
# ambulance in emergency situations.
# There are three significant modules, namely User, Ambulance, and Hospital. The web  application
# should facilitate the below functionality.
# • Users can register and log in using a username and password and they  can edit t heir
# profiles and change their passwords in an emergency.
# • After logging in, the user can book ambulances , and hospitals , view nearby hospitals, and
# view previously  booked ambulances and hospitals.
# • Users must select ambulance size, pick -up point & hospital,  and date & time for booking
# an ambulance.
# • In an emergency will automatically reserve the nearest ambulance & hospital. Users will
# get a list of All the bookings of Ambulances.
# • When the user books an ambulance and hospital, a booking request is sent to t he
# respective representatives of the ambulance and hospital.
# • The ambulance driver has to register and then login in using a username and password.
# After logging in, the driver can view booking requests, nearby hospitals, and their previous
# bookings, i.e.,  previously accepted submissions. In booking requests, it can either accept
# or decline the user requests.
# • The hospital has to register and log in using a username and password. After login in, the
# hospital representative can view the booking request and a ccept or decline the user
# request.
# • Also, add additional functionality which is not given in the specification.
# Based on the above -given  functionality the  team should be implemented this web application
# using Html, CSS, JavaScript, Java, Spring Boot, and MongoDB.
# The team should write a detailed report that describes your app.

# %%
# !pip install skillNer
# Out:
# Requirement already satisfied: skillNer in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (1.0.3)
# Requirement already satisfied: pandas in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from skillNer) (1.5.1)
# Requirement already satisfied: jellyfish in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from skillNer) (0.9.0)
# Requirement already satisfied: nltk in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from skillNer) (3.7)
# Requirement already satisfied: numpy in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from skillNer) (1.23.4)
# Requirement already satisfied: spacy in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from skillNer) (3.4.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from nltk->skillNer) (2022.10.31)
# Requirement already satisfied: joblib in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from nltk->skillNer) (1.2.0)
# Requirement already satisfied: click in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from nltk->skillNer) (8.1.3)
# Requirement already satisfied: tqdm in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from nltk->skillNer) (4.64.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from pandas->skillNer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from pandas->skillNer) (2022.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (1.7.4)
# Requirement already satisfied: setuptools in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (49.2.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (1.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (1.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (2.4.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (3.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (0.7.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (21.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (0.6.2)
# Requirement already satisfied: jinja2 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (3.1.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (8.1.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy->skillNer) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from packaging>=20.0->spacy->skillNer) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from pathy>=0.3.5->spacy->skillNer) (5.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.1->pandas->skillNer) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->skillNer) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->skillNer) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->skillNer) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->skillNer) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy->skillNer) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy->skillNer) (0.0.3)
# Requirement already satisfied: colorama in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from tqdm->nltk->skillNer) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from jinja2->spacy->skillNer) (2.1.1)

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.1/en_core_web_lg-3.4.1-py3-none-any.whl (587.7 MB)
#      ------------------------------------ 587.7/587.7 MB 545.8 kB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from en-core-web-lg==3.4.1) (3.4.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.4.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.7.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (4.64.1)
# Requirement already satisfied: setuptools in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (49.2.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.10.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (8.1.5)
# Requirement already satisfied: jinja2 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.28.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.7.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.23.4)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.6.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.10)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.0.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (5.2.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.0.3)
# Requirement already satisfied: colorama in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\danuja wijerathna\appdata\local\programs\python\python39\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.1) (2.1.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.4.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# imports
import spacy
from spacy.matcher import PhraseMatcher

# load default skills data base
from skillNer.general_params import SKILL_DB
# import skill extractor
from skillNer.skill_extractor_class import SkillExtractor

# init params of skill extractor
nlp = spacy.load("en_core_web_lg")
# init skill extractor
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher)

annotations = skill_extractor.annotate("".join(all_text))
# Out:
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...
# c:\Users\Danuja Wijerathna\AppData\Local\Programs\Python\Python39\lib\site-packages\skillNer\utils.py:99: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   vec_similarity = token1.similarity(token2)

# %%
skill_extractor.describe(annotations)
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="px-4 leading-10 mb-24">
#
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS120FV6SNZ00C8YJMJC_355()'onmouseenter='mouseEnterHandler_KS120FV6SNZ00C8YJMJC_355()'>
#             ambulance
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS120FV6SNZ00C8YJMJC_355'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Ambulances
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             0.8889971375465393
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS120FV6SNZ00C8YJMJC_355() {
#             document.getElementById("KS120FV6SNZ00C8YJMJC_355").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS120FV6SNZ00C8YJMJC_355() {
#             document.getElementById("KS120FV6SNZ00C8YJMJC_355").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbsp&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS127M46PTZDDRK2TVWP_304()'onmouseenter='mouseEnterHandler_KS127M46PTZDDRK2TVWP_304()'>
#             booking system
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS127M46PTZDDRK2TVWP_304'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Computer Booking Systems
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             0.5666666666666668
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS127M46PTZDDRK2TVWP_304() {
#             document.getElementById("KS127M46PTZDDRK2TVWP_304").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS127M46PTZDDRK2TVWP_304() {
#             document.getElementById("KS127M46PTZDDRK2TVWP_304").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbsp&nbsp &nbspthis system should be developed as a team this team should be three or four members project specification in today’s traffic world ambulance&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS120FV6SNZ00C8YJMJC_223()'onmouseenter='mouseEnterHandler_KS120FV6SNZ00C8YJMJC_223()'>
#             ambulance
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS120FV6SNZ00C8YJMJC_223'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Ambulances
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             0.8889971375465393
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS120FV6SNZ00C8YJMJC_223() {
#             document.getElementById("KS120FV6SNZ00C8YJMJC_223").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS120FV6SNZ00C8YJMJC_223() {
#             document.getElementById("KS120FV6SNZ00C8YJMJC_223").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbspa significant role when an accident occurs on the road network and the need arises to save valuable human&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS124VN5XNQD9Z4FB2P5_157()'onmouseenter='mouseEnterHandler_KS124VN5XNQD9Z4FB2P5_157()'>
#             human
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS124VN5XNQD9Z4FB2P5_157'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             skill name
#         </span>
#
#         <span class='col-1' >
#             Humanism
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             matching type
#         </span>
#
#         <span class='col-1' >
#             ngram_scored
#         </span>
#
#         </div>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1' >
#             score
#         </span>
#
#         <span class='col-1' >
#             0.729189395904541
#         </span>
#
#         </div>
#
#         </div>
#
#         <script class='' >
#
#         function mouseEnterHandler_KS124VN5XNQD9Z4FB2P5_157() {
#             document.getElementById("KS124VN5XNQD9Z4FB2P5_157").style.display = "";
#         }
#
#         function mouseLeaveHandler_KS124VN5XNQD9Z4FB2P5_157() {
#             document.getElementById("KS124VN5XNQD9Z4FB2P5_157").style.display = "none";
#         }
#
#         </script>
#
#         </span>
#      &nbsptransportation of a patient to an emergency hospital&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-blue-500' onmouseleave='mouseLeaveHandler_KS124S079M84GF98VQPB_851()'onmouseenter='mouseEnterHandler_KS124S079M84GF98VQPB_851()'>
#             hospital
#         <span class='text-xs text-white font-bold' >
#              ( Soft Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS124S079M84GF98VQPB_851'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
#         <span class='font-bold col-1'

# %%
annotations
# Out:
# {'text': 'ambulance booking system this system should be developed as a team this team should be three or four members project specification in today’s traffic world ambulance plays a significant role when an accident occurs on the road network and the need arises to save valuable human life transportation of a patient to an emergency hospital seems quite simple but in actuality it is pretty tricky and gets more complex during peak hours therefore should create a web application to people can easily book an ambulance in emergency situations there are three significant modules namely user ambulance and hospital the web application should facilitate the below functionality • users can register and log in using a username and password and they can edit t heir profiles and change their passwords in an emergency • after logging in the user can book ambulances and hospitals view nearby hospitals and view previously booked ambulances and hospitals • users must select ambulance size pick up point & hospital and date & time for booking an ambulance • in an emergency will automatically reserve the nearest ambulance & hospital users will get a list of all the bookings of ambulances • when the user books an ambulance and hospital a booking request is sent to t he respective representatives of the ambulance and hospital • the ambulance driver has to register and then login in using a username and password after logging in the driver can view booking requests nearby hospitals and their previous bookings i e previously accepted submissions in booking requests it can either accept or decline the user requests • the hospital has to register and log in using a username and password after login in the hospital representative can view the booking request and a ccept or decline the user request • also add additional functionality which is not given in the specification based on the above given functionality the team should be implemented this web application using html css javascript java spring boot and mongodb the team should write a detailed report that describes your app',
#  'results': {'full_matches': [{'skill_id': 'KS441ZY6P0PDB5DWTRB8',
#     'doc_node_value': 'web application',
#     'score': 1,
#     'doc_node_id': [77, 78]},
#    {'skill_id': 'KS441ZY6P0PDB5DWTRB8',
#     'doc_node_value': 'web application',
#     'score': 1,
#     'doc_node_id': [100, 101]},
#    {'skill_id': 'KS441ZY6P0PDB5DWTRB8',
#     'doc_node_value': 'web application',
#     'score': 1,
#     'doc_node_id': [325, 326]},
#    {'skill_id': 'ES6D557B9D5BE598FD74',
#     'doc_node_value': 'spring boot',
#     'score': 1,
#     'doc_node_id': [332, 333]},
#    {'skill_id': 'KS1200578T5QCYT0Z98G',
#     'score': 1,
#     'doc_node_value': 'Html',
#     'doc_node_id': [328]},
#    {'skill_id': 'KS121F45VPV8C9W3QFYH',
#     'score': 1,
#     'doc_node_value': 'CSS',
#     'doc_node_id': [329]}],
#   'ngram_scored': [{'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [0],
#     'doc_node_value': 'ambulance',
#     'type': 'lowSurf',
#     'score': 0.8889971375465393,
#     'len': 1},
#    {'skill_id': 'KS127M46PTZDDRK2TVWP',
#     'doc_node_id': [1, 2],
#     'doc_node_value': 'booking system',
#     'type': 'oneToken',
#     'score': 0.5666666666666668,
#     'len': 2},
#    {'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [26],
#     'doc_node_value': 'ambulance',
#     'type': 'lowSurf',
#     'score': 0.8889971375465393,
#     'len': 1},
#    {'skill_id': 'KS124VN5XNQD9Z4FB2P5',
#     'doc_node_id': [46],
#     'doc_node_value': 'human',
#     'type': 'lowSurf',
#     'score': 0.729189395904541,
#     'len': 1},
#    {'skill_id': 'KS124S079M84GF98VQPB',
#     'doc_node_id': [55],
#     'doc_node_value': 'hospital',
#     'type': 'lowSurf',
#     'score': 0.6353187561035156,
#     'len': 1},
#    {'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [85],
#     'doc_node_value': 'ambulance',
#     'type': 'lowSurf',
#     'score': 0.8889971375465393,
#     'len': 1},
#    {'skill_id': 'KS120GP613269KHPXZYW',
#     'doc_node_id': [93],
#     'doc_node_value': 'modules',
#     'type': 'lowSurf',
#     'score': 0.6197072863578796,
#     'len': 1},
#    {'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [96],
#     'doc_node_value': 'ambulance',
#     'type': 'lowSurf',
#     'score': 0.8889971375465393,
#     'len': 1},
#    {'skill_id': 'KS124S079M84GF98VQPB',
#     'doc_node_id': [98],
#     'doc_node_value': 'hospital',
#     'type': 'lowSurf',
#     'score': 0.6353187561035156,
#     'len': 1},
#    {'skill_id': 'KS120PP6GL94HJDMN0TQ',
#     'doc_node_id': [122],
#     'doc_node_value': 'edit',
#     'type': 'lowSurf',
#     'score': 0.60212641954422,
#     'len': 1},
#    {'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [141],
#     'doc_node_value': 'ambulances',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS124S079M84GF98VQPB',
#     'doc_node_id': [143],
#     'doc_node_value': 'hospitals',
#     'type': 'lowSurf',
#     'score': 0.6903567910194397,
#     'len': 1},
#    {'skill_id': 'KS124S079M84GF98VQPB',
#     'doc_node_id': [146],
#     'doc_node_value': 'hospitals',
#     'type': 'lowSurf',
#     'score': 0.6903567910194397,
#     'len': 1},
#    {'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [151],
#     'doc_node_value': 'ambulances',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS124S079M84GF98VQPB',
#     'doc_node_id': [153],
#     'doc_node_value': 'hospitals',
#     'type': 'lowSurf',
#     'score': 0.6903567910194397,
#     'len': 1},
#    {'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [158],
#     'doc_node_value': 'ambulance',
#     'type': 'lowSurf',
#     'score': 0.8889971375465393,
#     'len': 1},
#    {'skill_id': 'KS124S079M84GF98VQPB',
#     'doc_node_id': [164],
#     'doc_node_value': 'hospital',
#     'type': 'lowSurf',
#     'score': 0.6353187561035156,
#     'len': 1},
#    {'skill_id': 'KS7G48560M3J3TR2XHDB',
#     'doc_node_id': [170],
#     'doc_node_value': 'booking',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [172],
#     'doc_node_value': 'ambulance',
#     'type': 'lowSurf',
#     'score': 0.8889971375465393,
#     'len': 1},
#    {'skill_id': 'KS7G4T15W4RYVZTCDSWZ',
#     'doc_node_id': [179],
#     'doc_node_value': 'reserve',
#     'type': 'lowSurf',
#     'score': 0.6178233027458191,
#     'len': 1},
#    {'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [182],
#     'doc_node_value': 'ambulance',
#     'type': 'lowSurf',
#     'score': 0.8889971375465393,
#     'len': 1},
#    {'skill_id': 'KS124S079M84GF98VQPB',
#     'doc_node_id': [184],
#     'doc_node_value': 'hospital',
#     'type': 'lowSurf',
#     'score': 0.6353187561035156,
#     'len': 1},
#    {'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [195],
#     'doc_node_value': 'ambulances',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [202],
#     'doc_node_value': 'ambulance',
#     'type': 'lowSurf',
#     'score': 0.8889971375465393,
#     'len': 1},
#    {'skill_id': 'KS124S079M84GF98VQPB',
#     'doc_node_id': [204],
#     'doc_node_value': 'hospital',
#     'type': 'lowSurf',
#     'score': 0.6353187561035156,
#     'len': 1},
#    {'skill_id': 'KS7G48560M3J3TR2XHDB',
#     'doc_node_id': [206],
#     'doc_node_value': 'booking',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [217],
#     'doc_node_value': 'ambulance',
#     'type': 'lowSurf',
#     'score': 0.8889971375465393,
#     'len': 1},
#    {'skill_id': 'KS124S079M84GF98VQPB',
#     'doc_node_id': [219],
#     'doc_node_value': 'hospital',
#     'type': 'lowSurf',
#     'score': 0.6353187561035156,
#     'len': 1},
#    {'skill_id': 'KS120FV6SNZ00C8YJMJC',
#     'doc_node_id': [222],
#     'doc_node_value': 'ambulance',
#     'type': 'lowSurf',
#     'score': 0.8889971375465393,
#     'len': 1},
#    {'skill_id': 'KS68281768ZW4FDJZJSY',
#     'doc_node_id': [237],
#     'doc_node_value': 'logging',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS7G48560M3J3TR2XHDB',
#     'doc_node_id': [243],
#     'doc_node_value': 'booking',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS124S079M84GF98VQPB',
#     'doc_node_id': [246],
#     'doc_node_value': 'hospitals',
#     'type': 'lowSurf',
#     'score': 0.6903567910194397,
#     'len': 1},
#    {'skill_id': 'KS123MP6KPNJF3GFZ5TS',
#     'doc_node_id': [252],
#     'doc_node_value': 'e',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS7G48560M3J3TR2XHDB',
#     'doc_node_id': [257],
#     'doc_node_value': 'booking',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS124S079M84GF98VQPB',
#     'doc_node_id': [270],
#     'doc_node_value': 'hospital',
#     'type': 'lowSurf',
#     'score': 0.6353187561035156,
#     'len': 1},
#    {'skill_id': 'KS124S079M84GF98VQPB',
#     'doc_node_id': [286],
#     'doc_node_value': 'hospital',
#     'type': 'lowSurf',
#     'score': 0.6353187561035156,
#     'len': 1},
#    {'skill_id': 'KS7G48560M3J3TR2XHDB',
#     'doc_node_id': [291],
#     'doc_node_value': 'booking',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS7G3MD6P5T2XZKJMBD9',
#     'doc_node_id': [304],
#     'doc_node_value': 'additional',
#     'type': 'lowSurf',
#     'score': 0.6092319488525391,
#     'len': 1},
#    {'skill_id': 'KS1200771D9CR9LB4MWW',
#     'doc_node_id': [330],
#     'doc_node_value': 'javascript',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS120076FGP5WGWYMP0F',
#     'doc_node_id': [331],
#     'doc_node_value': 'java',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS126PF6PJY1N0ZX5R0P',
#     'doc_node_id': [335],
#     'doc_node_value': 'mongodb',
#     'type': 'fullUni',
#     'score': 1,
#     'len': 1},
#    {'skill_id': 'KS4425C7820LCHZS7VGX',
#     'doc_node_id': [339],
#     'doc_node_value': 'write',
#     'type': 'lowSurf',
#     'score': 0.7074721455574036,
#     'len': 1}]}}

# %%
type(annotations)
# Out:
# dict

# %%
for ano in annotations:
  print(ano)
# Out:
# text
# results

# %%
data = [line['doc_node_value'] for line in annotations['results']['full_matches']]

# %%
for d in data:
  temp = d
  data.remove(d)
  temp = temp.lower()
  print(temp)
  data.append(temp)
# Out:
# web application
# web application
# html
# web application
# html
# html

# %%
data
# Out:
# ['spring boot',
#  'CSS',
#  'web application',
#  'web application',
#  'web application',
#  'html']

# %%
set(data)
# Out:
# {'CSS', 'html', 'spring boot', 'web application'}
