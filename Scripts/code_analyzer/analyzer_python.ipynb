# %%
import os
import subprocess

# %%
from pylint.lint import Run

Run(['./projects/'], do_exit=False)
# Out:
# ************* Module hostel_management_system_in_django.hostel_management_system_in_django.manage
# projects\hostel_management_system_in_django\hostel_management_system_in_django\manage.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# ************* Module hostel_management_system_in_django.hostel_management_system_in_django.guest.admin
# projects\hostel_management_system_in_django\hostel_management_system_in_django\guest\admin.py:23:0: C0305: Trailing newlines (trailing-newlines)
# projects\hostel_management_system_in_django\hostel_management_system_in_django\guest\admin.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# projects\hostel_management_system_in_django\hostel_management_system_in_django\guest\admin.py:2:0: W0401: Wildcard import models (wildcard-import)
# projects\hostel_management_system_in_django\hostel_management_system_in_django\guest\admin.py:7:0: C0115: Missing class docstring (missing-class-docstring)
# ...
