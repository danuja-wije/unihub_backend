# %%
import networkx as nx
import matplotlib.pyplot as plt
import random

# %%
# Add edges between students and skills
# G.add_edge("Alice", "Python")
# G.add_edge("Lily", "Java")
# G.add_edge("Alice", "C++")
# G.add_edge("Judy", "Javascript")
# G.add_edge("Alice", "SQL")
# G.add_edge("Bob", "Python")
# G.add_edge("Karl", "Java")
# G.add_edge("Bob", "C++")
# G.add_edge("Bob", "Javascript")
# G.add_edge("Mike", "SQL")
# G.add_edge("Charlie", "Python")
# G.add_edge("Charlie", "Java")
# G.add_edge("Nancy", "C++")
# G.add_edge("Charlie", "Javascript")
# G.add_edge("Charlie", "SQL")
# G.add_edge("David", "Python")
# G.add_edge("David", "Java")
# G.add_edge("Oscar", "C++")
# G.add_edge("David", "Javascript")
# G.add_edge("David", "SQL")
# G.add_edge("Eve", "Python")
# G.add_edge("Eve", "Java")
# G.add_edge("Eve", "C++")
# G.add_edge("Peggy", "Javascript")
# G.add_edge("Eve", "SQL")
# G.add_edge("Frank", "Python")
# G.add_edge("Quinn", "Java")
# G.add_edge("Frank", "C++")
# G.add_edge("Mike", "Javascript")
# G.add_edge("Frank", "SQL")
# G.add_edge("Ralph", "Python")
# G.add_edge("Grace", "Java")
# G.add_edge("Ivan", "C++")
# G.add_edge("Grace", "Javascript")
# G.add_edge("Hannah", "SQL")
#adding dummy edges to make the graph bipartite represent the skill levels

# G.add_edge("Alice", "Python",capacity=float((10 - skill_levels["Alice"]) + collaboration_potential["Alice"]),weight=(skill_levels["Alice"])/10)
# G.add_edge("Lily", "Java",capacity=float((10 - skill_levels["Lily"]) + collaboration_potential["Lily"]),weight=(skill_levels["Lily"])/10)
# G.add_edge("Alice", "C++",capacity=float((10 - skill_levels["Alice"]) + collaboration_potential["Alice"]),weight=(skill_levels["Alice"])/10)
# G.add_edge("Judy", "Javascript",capacity=float((10 - skill_levels["Judy"]) + collaboration_potential["Judy"]),weight=(skill_levels["Judy"])/10)
# G.add_edge("Alice", "SQL",capacity=float((10 - skill_levels["Alice"]) + collaboration_potential["Alice"]),weight=(skill_levels["Alice"])/10)
# G.add_edge("Bob", "Python",capacity=float((10 - skill_levels["Bob"]) + collaboration_potential["Bob"]),weight=(skill_levels["Bob"])/10)
# G.add_edge("Karl", "Java",capacity=float((10 - skill_levels["Karl"]) + collaboration_potential["Karl"]),weight=(skill_levels["Karl"])/10)
# G.add_edge("Bob", "C++",capacity=float((10 - skill_levels["Bob"]) + collaboration_potential["Bob"]),weight=(skill_levels["Bob"])/10)
# G.add_edge("Bob", "Javascript",capacity=float((10 - skill_levels["Bob"]) + collaboration_potential["Bob"]),weight=(skill_levels["Bob"])/10)
# G.add_edge("Mike", "SQL",capacity=float((10 - skill_levels["Mike"]) + collaboration_potential["Mike"]),weight=(skill_levels["Mike"])/10)
# G.add_edge("Charlie", "Python",capacity=float((10 - skill_levels["Charlie"]) + collaboration_potential["Charlie"]),weight=(skill_levels["Charlie"])/10)
# G.add_edge("Charlie", "Java",capacity=float((10 - skill_levels["Charlie"]) + collaboration_potential["Charlie"]),weight=(skill_levels["Charlie"])/10)
# G.add_edge("Nancy", "C++",capacity=float((10 - skill_levels["Nancy"]) + collaboration_potential["Nancy"]),weight=(skill_levels["Nancy"])/10)
# G.add_edge("Charlie", "Javascript",capacity=float((10 - skill_levels["Charlie"]) + collaboration_potential["Charlie"]),weight=(skill_levels["Charlie"])/10)
# G.add_edge("Charlie", "SQL",capacity=float((10 - skill_levels["Charlie"]) + collaboration_potential["Charlie"]),weight=(skill_levels["Charlie"])/10)
# G.add_edge("David", "Python",capacity=float((10 - skill_levels["David"]) + collaboration_potential["David"]),weight=(skill_levels["David"])/10)
# G.add_edge("David", "Java",capacity=float((10 - skill_levels["David"]) + collaboration_potential["David"]),weight=(skill_levels["David"])/10)
# G.add_edge("Oscar", "C++",capacity=float((10 - skill_levels["Oscar"]) + collaboration_potential["Oscar"]),weight=(skill_levels["Oscar"])/10)
# G.add_edge("David", "Javascript",capacity=float((10 - skill_levels["David"]) + collaboration_potential["David"]),weight=(skill_levels["David"])/10)
# G.add_edge("David", "SQL",capacity=float((10 - skill_levels["David"]) + collaboration_potential["David"]),weight=(skill_levels["David"])/10)
# G.add_edge("Eve", "Python",capacity=float((10 - skill_levels["Eve"]) + collaboration_potential["Eve"]),weight=(skill_levels["Eve"])/10)
# G.add_edge("Eve", "Java",capacity=float((10 - skill_levels["Eve"]) + collaboration_potential["Eve"]),weight=(skill_levels["Eve"])/10)
# G.add_edge("Eve", "C++",capacity=float((10 - skill_levels["Eve"]) + collaboration_potential["Eve"]),weight=(skill_levels["Eve"])/10)
# G.add_edge("Peggy", "Javascript",capacity=float((10 - skill_levels["Peggy"]) + collaboration_potential["Peggy"]),weight=(skill_levels["Peggy"])/10)
# G.add_edge("Eve", "SQL",capacity=float((10 - skill_levels["Eve"]) + collaboration_potential["Eve"]),weight=(skill_levels["Eve"])/10)
# G.add_edge("Frank", "Python",capacity=float((10 - skill_levels["Frank"]) + collaboration_potential["Frank"]),weight=(skill_levels["Frank"])/10)
# G.add_edge("Quinn", "Java",capacity=float((10 - skill_levels["Quinn"]) + collaboration_potential["Quinn"]),weight=(skill_levels["Quinn"])/10)
# G.add_edge("Frank", "C++",capacity=float((10 - skill_levels["Frank"]) + collaboration_potential["Frank"]),weight=(skill_levels["Frank"])/10)
# G.add_edge("Mike", "Javascript",capacity=float((10 - skill_levels["Mike"]) + collaboration_potential["Mike"]),weight=(skill_levels["Mike"])/10)
# G.add_edge("Frank", "SQL",capacity=float((10 - skill_levels["Frank"]) + collaboration_potential["Frank"]),weight=(skill_levels["Frank"])/10)
# G.add_edge("Ralph", "Python",capacity=float((10 - skill_levels["Ralph"]) + collaboration_potential["Ralph"]),weight=(skill_levels["Ralph"])/10)
# G.add_edge("Grace", "Java",capacity=float((10 - skill_levels["Grace"]) + collaboration_potential["Grace"]),weight=(skill_levels["Grace"])/10)
# G.add_edge("Ivan", "C++",capacity=float((10 - skill_levels["Ivan"]) + collaboration_potential["Ivan"]),weight=(skill_levels["Ivan"])/10)
# G.add_edge("Grace", "Javascript",capacity=float((10 - skill_levels["Grace"]) + collaboration_potential["Grace"]),weight=(skill_levels["Grace"])/10)
# G.add_edge("Hannah", "SQL",capacity=float((10 - skill_levels["Hannah"]) + collaboration_potential["Hannah"]),weight=(skill_levels["Hannah"])/10)

# G.add_edge("Alice", "Python",capacity=float(collaboration_potential["Alice"]),weight=1 - (skill_levels["Alice"])/10)
# G.add_edge("Lily", "Java",capacity=float(collaboration_potential["Lily"]),weight=1 - (skill_levels["Lily"])/10)
# G.add_edge("Alice", "C++",capacity=float(collaboration_potential["Alice"]),weight=1 - (skill_levels["Alice"])/10)
# G.add_edge("Judy", "Javascript",capacity=float(collaboration_potential["Judy"]),weight=1 - (skill_levels["Judy"])/10)
# G.add_edge("Alice", "SQL",capacity=float(collaboration_potential["Alice"]),weight=1 - (skill_levels["Alice"])/10)
# G.add_edge("Bob", "Python",capacity=float(collaboration_potential["Bob"]),weight=1 - (skill_levels["Bob"])/10)
# G.add_edge("Karl", "Java",capacity=float(collaboration_potential["Karl"]),weight=1 - (skill_levels["Karl"])/10)
# G.add_edge("Bob", "C++",capacity=float(collaboration_potential["Bob"]),weight=1 - (skill_levels["Bob"])/10)
# G.add_edge("Bob", "Javascript",capacity=float(collaboration_potential["Bob"]),weight=1 - (skill_levels["Bob"])/10)
# G.add_edge("Mike", "SQL",capacity=float(collaboration_potential["Mike"]),weight=1 - (skill_levels["Mike"])/10)
# G.add_edge("Charlie", "Python",capacity=float(collaboration_potential["Charlie"]),weight=1 - (skill_levels["Charlie"])/10)
# G.add_edge("Charlie", "Java",capacity=float(collaboration_potential["Charlie"]),weight=1 - (skill_levels["Charlie"])/10)
# G.add_edge("Nancy", "C++",capacity=float(collaboration_potential["Nancy"]),weight=1 - (skill_levels["Nancy"])/10)
# G.add_edge("Charlie", "Javascript",capacity=float(collaboration_potential["Charlie"]),weight=1 - (skill_levels["Charlie"])/10)
# G.add_edge("Charlie", "SQL",capacity=float(collaboration_potential["Charlie"]),weight=1 - (skill_levels["Charlie"])/10)
# G.add_edge("David", "Python",capacity=float(collaboration_potential["David"]),weight=1 - (skill_levels["David"])/10)
# G.add_edge("David", "Java",capacity=float(collaboration_potential["David"]),weight=1 - (skill_levels["David"])/10)
# G.add_edge("Oscar", "C++",capacity=float(collaboration_potential["Oscar"]),weight=1 - (skill_levels["Oscar"])/10)
# G.add_edge("David", "Javascript",capacity=float( collaboration_potential["David"]),weight=1 - (skill_levels["David"])/10)
# G.add_edge("David", "SQL",capacity=float(collaboration_potential["David"]),weight=1 - (skill_levels["David"])/10)
# G.add_edge("Eve", "Python",capacity=float(collaboration_potential["Eve"]),weight=1 - (skill_levels["Eve"])/10)
# G.add_edge("Eve", "Java",capacity=float(collaboration_potential["Eve"]),weight=1 - (skill_levels["Eve"])/10)
# G.add_edge("Eve", "C++",capacity=float(collaboration_potential["Eve"]),weight=1 - (skill_levels["Eve"])/10)
# G.add_edge("Peggy", "Javascript",capacity=float(collaboration_potential["Peggy"]),weight=1 - (skill_levels["Peggy"])/10)
# G.add_edge("Eve", "SQL",capacity=float(collaboration_potential["Eve"]),weight=1 - (skill_levels["Eve"])/10)
# G.add_edge("Frank", "Python",capacity=float(collaboration_potential["Frank"]),weight=1 - (skill_levels["Frank"])/10)
# G.add_edge("Quinn", "Java",capacity=float(collaboration_potential["Quinn"]),weight=1 - (skill_levels["Quinn"])/10)
# G.add_edge("Frank", "C++",capacity=float(collaboration_potential["Frank"]),weight=1 - (skill_levels["Frank"])/10)
# G.add_edge("Mike", "Javascript",capacity=float( collaboration_potential["Mike"]),weight=1 - (skill_levels["Mike"])/10)
# G.add_edge("Frank", "SQL",capacity=float(collaboration_potential["Frank"]),weight=1 - (skill_levels["Frank"])/10)
# G.add_edge("Ralph", "Python",capacity=float(collaboration_potential["Ralph"]),weight=1 - (skill_levels["Ralph"])/10)
# G.add_edge("Grace", "Java",capacity=float(collaboration_potential["Grace"]),weight=1 - (skill_levels["Grace"])/10)
# G.add_edge("Ivan", "C++",capacity=float(collaboration_potential["Ivan"]),weight=1 - (skill_levels["Ivan"])/10)
# G.add_edge("Grace", "Javascript",capacity=float( collaboration_potential["Grace"]),weight=1 - (skill_levels["Grace"])/10)
# G.add_edge("Hannah", "SQL",capacity=float( collaboration_potential["Hannah"]),weight=1 - (skill_levels["Hannah"])/10)
# G.add_edge("Alice", "Python",capacity=float(collaboration_potential["Alice"]["Python"]),weight=(skill_levels["Alice"]["Python"])/10)
# G.add_edge("Lily", "Java",capacity=float(collaboration_potential["Lily"]["Java"]),weight=(skill_levels["Lily"]["Java"])/10)
# G.add_edge("Alice", "C++",capacity=float(collaboration_potential["Alice"]["C++"]),weight=(skill_levels["Alice"]["C++"])/10)
# G.add_edge("Judy", "Javascript",capacity=float(collaboration_potential["Judy"]["Javascript"]),weight=(skill_levels["Judy"]["Javascript"])/10)
# G.add_edge("Alice", "SQL",capacity=float(collaboration_potential["Alice"]["SQL"]),weight=(skill_levels["Alice"]["SQL"])/10)
# G.add_edge("Bob", "Python",capacity=float(collaboration_potential["Bob"]["Python"]),weight=(skill_levels["Bob"]["Python"])/10)
# G.add_edge("Karl", "Java",capacity=float(collaboration_potential["Karl"]["Java"]),weight=(skill_levels["Karl"]["Java"])/10)
# G.add_edge("Bob", "C++",capacity=float(collaboration_potential["Bob"]["C++"]),weight=(skill_levels["Bob"]["C++"])/10)
# G.add_edge("Bob", "Javascript",capacity=float(collaboration_potential["Bob"]["Javascript"]),weight=(skill_levels["Bob"]["Javascript"])/10)
# G.add_edge("Mike", "SQL",capacity=float(collaboration_potential["Mike"]["SQL"]),weight=(skill_levels["Mike"]["SQL"])/10)
# G.add_edge("Charlie", "Python",capacity=float(collaboration_potential["Charlie"]["Python"]),weight=(skill_levels["Charlie"]["Python"])/10)
# G.add_edge("Charlie", "Java",capacity=float(collaboration_potential["Charlie"]["Java"]),weight=(skill_levels["Charlie"]["Java"])/10)
# G.add_edge("Nancy", "C++",capacity=float(collaboration_potential["Nancy"]["C++"]),weight=(skill_levels["Nancy"]["C++"])/10)
# G.add_edge("Charlie", "Javascript",capacity=float(collaboration_potential["Charlie"]["Javascript"]),weight=(skill_levels["Charlie"]["Javascript"])/10)
# G.add_edge("Charlie", "SQL",capacity=float(collaboration_potential["Charlie"]["SQL"]),weight=(skill_levels["Charlie"]["SQL"])/10)
# G.add_edge("David", "Python",capacity=float(collaboration_potential["David"]["Python"]),weight=(skill_levels["David"]["Python"])/10)
# G.add_edge("David", "Java",capacity=float(collaboration_potential["David"]["Java"]),weight=(skill_levels["David"]["Java"])/10)
# G.add_edge("Oscar", "Python",capacity=float(collaboration_potential["Oscar"]["C++"]),weight=(skill_levels["Oscar"]["C++"])/10)
# G.add_edge("David", "Javascript",capacity=float( collaboration_potential["David"]["Javascript"]),weight=(skill_levels["David"]["Javascript"])/10)
# G.add_edge("David", "SQL",capacity=float(collaboration_potential["David"]["SQL"]),weight=(skill_levels["David"]["SQL"])/10)
# G.add_edge("Eve", "Python",capacity=float(collaboration_potential["Eve"]["Python"]),weight=(skill_levels["Eve"]["Python"])/10)
# G.add_edge("Eve", "Java",capacity=float(collaboration_potential["Eve"]["Java"]),weight=(skill_levels["Eve"]["Java"])/10)
# G.add_edge("Eve", "C++",capacity=float(collaboration_potential["Eve"]["C++"]),weight=(skill_levels["Eve"]["C++"])/10)
# G.add_edge("Peggy", "Javascript",capacity=float(collaboration_potential["Peggy"]["Javascript"]),weight=(skill_levels["Peggy"]["Javascript"])/10)
# G.add_edge("Eve", "SQL",capacity=float(collaboration_potential["Eve"]["SQL"]),weight=(skill_levels["Eve"]["SQL"])/10)
# G.add_edge("Frank", "Python",capacity=float(collaboration_potential["Frank"]["Python"]),weight=(skill_levels["Frank"]["Python"])/10)
# G.add_edge("Quinn", "Java",capacity=float(collaboration_potential["Quinn"]["Java"]),weight=(skill_levels["Quinn"]["Java"])/10)
# G.add_edge("Frank", "C++",capacity=float(collaboration_potential["Frank"]["C++"]),weight=(skill_levels["Frank"]["C++"])/10)
# G.add_edge("Mike", "Javascript",capacity=float( collaboration_potential["Mike"]["Javascript"]),weight=(skill_levels["Mike"]["Javascript"])/10)
# G.add_edge("Frank", "SQL",capacity=float(collaboration_potential["Frank"]["SQL"]),weight=(skill_levels["Frank"]["SQL"])/10)
# G.add_edge("Ralph", "Python",capacity=float(collaboration_potential["Ralph"]["Python"]),weight=(skill_levels["Ralph"]["Python"])/10)
# G.add_edge("Grace", "Java",capacity=float(collaboration_potential["Grace"]["Java"]),weight=(skill_levels["Grace"]["Java"])/10)
# G.add_edge("Ivan", "C++",capacity=float(collaboration_potential["Ivan"]["C++"]),weight=(skill_levels["Ivan"]["C++"])/10)
# G.add_edge("Grace", "Javascript",capacity=float( collaboration_potential["Grace"]["Javascript"]),weight=(skill_levels["Grace"]["Javascript"])/10)
# G.add_edge("Hannah", "SQL",capacity=float( collaboration_potential["Hannah"]["SQL"]),weight=(skill_levels["Hannah"]["SQL"])/10)

# %%
skills = ["Python", "Java", "C++", "Javascript", "SQL"]
students = ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah", "Ivan", "Judy", "Karl", "Lily", "Mike", "Nancy", "Oscar", "Peggy", "Quinn", "Ralph"]

G = nx.Graph()
G.add_nodes_from(skills, bipartite=0)
G.add_nodes_from(students, bipartite=1)


skill_levels = {
        "Alice":{ "Python": 5, "Java": 4, "C++": 3, "Javascript": 2, "SQL": 1},
        "Bob":{ "Python": 4, "Java": 3, "C++": 2, "Javascript": 1, "SQL": 5},
        "Charlie":{ "Python": 3, "Java": 2, "C++": 1, "Javascript": 5, "SQL": 4},
        "David":{"Python": 2, "Java": 1},
        "Eve":{"Python": 1, "Java": 5, "C++": 4, "Javascript": 3},
        "Frank":{"Python": 5, "C++": 4, "SQL": 3},
        "Grace":{"Java": 5, "Javascript": 4},
        "Hannah":{"SQL": 5},
        "Ivan":{"C++": 5},
        "Judy":{"Javascript": 5},
        "Karl":{ "Java": 5, "C++": 4, "Javascript": 3, "SQL": 2},
        "Lily":{ "Java": 4, "C++": 3, "Javascript": 2, "SQL": 1},
        "Mike":{ "SQL": 4, "Javascript": 3, "C++": 2, "Java": 1},
        "Nancy":{ "C++": 5, "Java": 4, "SQL": 3},
        "Oscar":{"Python": 5,"SQL": 4},
        "Peggy":{"Javascript": 5, "SQL": 4},
        "Quinn":{"Java": 5, "C++": 4},
        "Ralph":{"Python": 5, "Java": 4, "C++": 3, "Javascript": 2, "SQL": 1},
 }

skill_levels
# Out:
# {'Alice': {'Python': 5, 'Java': 4, 'C++': 3, 'Javascript': 2, 'SQL': 1},
#  'Bob': {'Python': 4, 'Java': 3, 'C++': 2, 'Javascript': 1, 'SQL': 5},
#  'Charlie': {'Python': 3, 'Java': 2, 'C++': 1, 'Javascript': 5, 'SQL': 4},
#  'David': {'Python': 2, 'Java': 1},
#  'Eve': {'Python': 1, 'Java': 5, 'C++': 4, 'Javascript': 3},
#  'Frank': {'Python': 5, 'C++': 4, 'SQL': 3},
#  'Grace': {'Java': 5, 'Javascript': 4},
#  'Hannah': {'SQL': 5},
#  'Ivan': {'C++': 5},
#  'Judy': {'Javascript': 5},
#  'Karl': {'Java': 5, 'C++': 4, 'Javascript': 3, 'SQL': 2},
#  'Lily': {'Java': 4, 'C++': 3, 'Javascript': 2, 'SQL': 1},
#  'Mike': {'SQL': 4, 'Javascript': 3, 'C++': 2, 'Java': 1},
#  'Nancy': {'C++': 5, 'Java': 4, 'SQL': 3},
#  'Oscar': {'Python': 5, 'SQL': 4},
#  'Peggy': {'Javascript': 5, 'SQL': 4},
#  'Quinn': {'Java': 5, 'C++': 4},
#  'Ralph': {'Python': 5, 'Java': 4, 'C++': 3, 'Javascript': 2, 'SQL': 1}}

# %%
collaboration_potential = {}

for student,skills in skill_levels.items():
        # print(student)
        for skill,point in skills.items():
                # print(skill,point)
                if student not in collaboration_potential:
                        collaboration_potential[student] = {}
                        if skill not in collaboration_potential[student]:
                                collaboration_potential[student][skill] = 10 - point
                else:
                        if skill not in collaboration_potential[student]:
                                collaboration_potential[student][skill] = 10 - point

collaboration_potential
# Out:
# {'Alice': {'Python': 5, 'Java': 6, 'C++': 7, 'Javascript': 8, 'SQL': 9},
#  'Bob': {'Python': 6, 'Java': 7, 'C++': 8, 'Javascript': 9, 'SQL': 5},
#  'Charlie': {'Python': 7, 'Java': 8, 'C++': 9, 'Javascript': 5, 'SQL': 6},
#  'David': {'Python': 8, 'Java': 9},
#  'Eve': {'Python': 9, 'Java': 5, 'C++': 6, 'Javascript': 7},
#  'Frank': {'Python': 5, 'C++': 6, 'SQL': 7},
#  'Grace': {'Java': 5, 'Javascript': 6},
#  'Hannah': {'SQL': 5},
#  'Ivan': {'C++': 5},
#  'Judy': {'Javascript': 5},
#  'Karl': {'Java': 5, 'C++': 6, 'Javascript': 7, 'SQL': 8},
#  'Lily': {'Java': 6, 'C++': 7, 'Javascript': 8, 'SQL': 9},
#  'Mike': {'SQL': 6, 'Javascript': 7, 'C++': 8, 'Java': 9},
#  'Nancy': {'C++': 5, 'Java': 6, 'SQL': 7},
#  'Oscar': {'Python': 5, 'SQL': 6},
#  'Peggy': {'Javascript': 5, 'SQL': 6},
#  'Quinn': {'Java': 5, 'C++': 6},
#  'Ralph': {'Python': 5, 'Java': 6, 'C++': 7, 'Javascript': 8, 'SQL': 9}}

# %%
for student,skills in collaboration_potential.items():
        for skill,point in skills.items():
                G.add_edge(student, skill,capacity=float(point),weight=(skill_levels[student][skill])/10)

# %%
#add dummy edges to make the graph bipartite represent the collaboration 

G.add_edge("Alice", "Bob",weights= 0.1)
G.add_edge("Alice", "Charlie",weights= 0.5)
G.add_edge("Alice", "David",weights= 0.3)
G.add_edge("Alice", "Eve",weights= 0.4)
G.add_edge("Alice", "Frank",weights= 0.9)
G.add_edge("Alice", "Ralph",weights= 0.4)
G.add_edge("Lily", "Karl",weights=0.7)
G.add_edge("Lily", "Grace",weights= 0.2)
G.add_edge("Judy", "Mike",weights= 0.8)
G.add_edge("Judy", "Hannah",weights= 0.6)
G.add_edge("Judy", "Peggy",weights= 0.3)
G.add_edge("Judy", "Oscar",weights= 0.6)
G.add_edge("Judy", "Ivan",weights= 0.8)
G.add_edge("Judy", "Quinn",weights= 0.5)

# %%
import random
print(random.uniform(0,1))
# Out:
# 0.09527394912165921

# %%
# weights = {(u,v): random.uniform(0, 1) for u, v in G.edges()}
# weights

# %%
# nx.set_edge_attributes(G, weights, 'weight')

# %%
for node in G.edges(data=True):
    if node[0] == "Python":
        print(node[2]['weight'])
# Out:
# 0.5
# 0.4
# 0.3
# 0.2
# 0.1
# 0.5
# 0.5
# 0.5

# %%
# Add edges between students and students
plt.figure(figsize=(10,10))
pos = nx.kamada_kawai_layout(G)
nx.draw(G, with_labels=True,pos = pos)

# %%
from networkx.algorithms.flow import shortest_augmenting_path

# %%
flow_value, flow_dict = nx.maximum_flow(G, "Mike","SQL" , capacity='capacity')

# %%
flow_value
# Out:
# 78.0

# %%
flow_value, flow_dict = nx.maximum_flow(G, "Charlie","SQL" , capacity='capacity')

# %%
flow_value
# Out:
# 83.0

# %%
# capacities = [G[u][v]['capacity'] for u, v in G.edges()]

# %%
# weights = [G[u][v]['weight'] for u, v in G.edges()]

# %%
flow_dict
# Out:
# {'Python': {'Alice': 5.0,
#   'Bob': 0,
#   'Charlie': 0,
#   'David': 0,
#   'Eve': 9.0,
#   'Frank': 0,
#   'Oscar': 5.0,
#   'Ralph': 5.0},
#  'Java': {'Alice': 6.0,
#   'Bob': 0,
#   'Charlie': 8.0,
#   'David': 0,
#   'Eve': 0,
#   'Grace': 5.0,
#   'Karl': 5.0,
#   'Lily': 0,
#   'Mike': 0,
#   'Nancy': 2.0,
#   'Quinn': 5.0,
#   'Ralph': 0},
#  'C++': {'Alice': 5.0,
#   'Bob': 0,
#   'Charlie': 9.0,
#   'Eve': 0,
#   'Frank': 0,
#   'Ivan': 0,
#   'Karl': 6.0,
#   'Lily': 0,
#   'Mike': 8.0,
#   'Nancy': 5.0,
#   'Quinn': 6.0,
#   'Ralph': 0},
#  'Javascript': {'Alice': 0,
#   'Bob': 0,
#   'Charlie': 5.0,
#   'Eve': 0,
#   'Grace': 5.0,
#   'Judy': 0,
#   'Karl': 7.0,
#   'Lily': 2.0,
#   'Mike': 7.0,
#   'Peggy': 5.0,
#   'Ralph': 0},
#  'SQL': {'Alice': 0,
#   'Bob': 0,
#   'Charlie': 0,
#   'Frank': 0,
#   'Hannah': 0,
#   'Karl': 0,
#   'Lily': 0,
#   'Mike': 0,
#   'Nancy': 0,
#   'Oscar': 0,
#   'Peggy': 0,
#   'Ralph': 0},
#  'Alice': {'Python': 0,
#   'Java': 0,
# ...

# %%
G.degree
# Out:
# DegreeView({'Python': 8, 'Java': 12, 'C++': 12, 'Javascript': 11, 'SQL': 12, 'Alice': 11, 'Bob': 6, 'Charlie': 6, 'David': 3, 'Eve': 5, 'Frank': 4, 'Grace': 3, 'Hannah': 2, 'Ivan': 2, 'Judy': 7, 'Karl': 5, 'Lily': 6, 'Mike': 5, 'Nancy': 3, 'Oscar': 3, 'Peggy': 3, 'Quinn': 3, 'Ralph': 6})

# %%
from community import community_louvain

# %%
['red' if node in skills else 'None' for node in G.nodes ]
# Out:
# ['red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None']

# %%
communities = community_louvain.best_partition(G)
# Draw the graph
pos = nx.spring_layout(G)

# Create a list of colors for each community
colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(len(communities.values()))]

plt.figure(figsize=(20,20))

# Draw the nodes colored by community
for com in set(communities.values()):
    list_nodes = [nodes for nodes in communities.keys() if communities[nodes] == com]
    
    pos = nx.kamada_kawai_layout(G)
    #nx.draw_networkx_nodes(G, pos, nodelist=list_nodes, node_color = colors[com], node_size=1000, alpha=0.8)
    nx.draw_networkx_nodes(G,pos,nodelist=[node for node in G.nodes if node in skills], node_color = ['red'  for node in G.nodes if node in skills], node_size=1000, alpha=1)
    nx.draw_networkx_nodes(G,pos,nodelist=list_nodes, node_color = colors[com], node_size=2000, alpha=0.6)
    nx.draw_networkx_edges(G,pos, alpha=0.5)
    # nx.draw(G,pos,nodelist=list_nodes, node_color = ['red' if node in skills else 'None' for node in G.nodes ], node_size=2000, alpha=0.5, with_labels=True)
    nx.draw_networkx_labels(G,pos,font_size=20,font_family='sans-serif')

# %%
nx.set_node_attributes(G, communities, 'group')

# %%
# from pyvis.network import Network
# net = Network(notebook=True, height="1000px", width="100%", bgcolor="#222222", font_color="white")

# node_degree = dict(G.degree)

# nx.set_node_attributes(G, node_degree, 'size')

# net.from_nx(G)
# net.show("graph.html")

# %%
for node in G.nodes(data=True):
    print(node)
# Out:
# ('Python', {'bipartite': 0, 'group': 3})
# ('Java', {'bipartite': 0, 'group': 1})
# ('C++', {'bipartite': 0, 'group': 0})
# ('Javascript', {'bipartite': 0, 'group': 1})
# ('SQL', {'bipartite': 0, 'group': 2})
# ('Alice', {'bipartite': 1, 'group': 3})
# ('Bob', {'bipartite': 1, 'group': 3})
# ('Charlie', {'bipartite': 1, 'group': 3})
# ('David', {'bipartite': 1, 'group': 3})
# ('Eve', {'bipartite': 1, 'group': 3})
# ('Frank', {'bipartite': 1, 'group': 3})
# ('Grace', {'bipartite': 1, 'group': 1})
# ('Hannah', {'bipartite': 1, 'group': 2})
# ('Ivan', {'bipartite': 1, 'group': 2})
# ('Judy', {'bipartite': 1, 'group': 2})
# ('Karl', {'bipartite': 1, 'group': 1})
# ('Lily', {'bipartite': 1, 'group': 1})
# ('Mike', {'bipartite': 1, 'group': 2})
# ('Nancy', {'bipartite': 1, 'group': 0})
# ('Oscar', {'bipartite': 1, 'group': 2})
# ('Peggy', {'bipartite': 1, 'group': 2})
# ('Quinn', {'bipartite': 1, 'group': 2})
# ('Ralph', {'bipartite': 1, 'group': 3})

# %%
for edge in G.edges(data=True):
    if edge[0] in skills:
        print(edge)
# Out:
# ('Python', 'Alice', {'capacity': 5.0, 'weight': 0.5})
# ('Python', 'Bob', {'capacity': 6.0, 'weight': 0.4})
# ('Python', 'Charlie', {'capacity': 7.0, 'weight': 0.3})
# ('Python', 'David', {'capacity': 8.0, 'weight': 0.2})
# ('Python', 'Eve', {'capacity': 9.0, 'weight': 0.1})
# ('Python', 'Frank', {'capacity': 5.0, 'weight': 0.5})
# ('Python', 'Oscar', {'capacity': 5.0, 'weight': 0.5})
# ('Python', 'Ralph', {'capacity': 5.0, 'weight': 0.5})
# ('Java', 'Alice', {'capacity': 6.0, 'weight': 0.4})
# ('Java', 'Bob', {'capacity': 7.0, 'weight': 0.3})
# ('Java', 'Charlie', {'capacity': 8.0, 'weight': 0.2})
# ('Java', 'David', {'capacity': 9.0, 'weight': 0.1})
# ('Java', 'Eve', {'capacity': 5.0, 'weight': 0.5})
# ('Java', 'Grace', {'capacity': 5.0, 'weight': 0.5})
# ('Java', 'Karl', {'capacity': 5.0, 'weight': 0.5})
# ('Java', 'Lily', {'capacity': 6.0, 'weight': 0.4})
# ('Java', 'Mike', {'capacity': 9.0, 'weight': 0.1})
# ('Java', 'Nancy', {'capacity': 6.0, 'weight': 0.4})
# ...

# %%
edges_list = [i for i in G.edges(data=True)]
print(edges_list)
# Out:
# [('Python', 'Alice', {'capacity': 5.0, 'weight': 0.5}), ('Python', 'Bob', {'capacity': 6.0, 'weight': 0.4}), ('Python', 'Charlie', {'capacity': 7.0, 'weight': 0.3}), ('Python', 'David', {'capacity': 8.0, 'weight': 0.2}), ('Python', 'Eve', {'capacity': 9.0, 'weight': 0.1}), ('Python', 'Frank', {'capacity': 5.0, 'weight': 0.5}), ('Python', 'Oscar', {'capacity': 5.0, 'weight': 0.5}), ('Python', 'Ralph', {'capacity': 5.0, 'weight': 0.5}), ('Java', 'Alice', {'capacity': 6.0, 'weight': 0.4}), ('Java', 'Bob', {'capacity': 7.0, 'weight': 0.3}), ('Java', 'Charlie', {'capacity': 8.0, 'weight': 0.2}), ('Java', 'David', {'capacity': 9.0, 'weight': 0.1}), ('Java', 'Eve', {'capacity': 5.0, 'weight': 0.5}), ('Java', 'Grace', {'capacity': 5.0, 'weight': 0.5}), ('Java', 'Karl', {'capacity': 5.0, 'weight': 0.5}), ('Java', 'Lily', {'capacity': 6.0, 'weight': 0.4}), ('Java', 'Mike', {'capacity': 9.0, 'weight': 0.1}), ('Java', 'Nancy', {'capacity': 6.0, 'weight': 0.4}), ('Java', 'Quinn', {'capacity': 5.0
# ...

# %%
# l = []
# for i in G.edges(data=True):
#     l.append(i[2]['width'])
# print(len(l))

# %%
# edges_list.sort(key=lambda x: x[2]['weight'], reverse=True)
# edges_list

# %% [markdown]
# # Define complexity

# %%
#project 1

project_complexity = {}

project_complexity["Python"] = 2
project_complexity["Javascript"] = 2
project_complexity["SQL"] = 2
project_complexity["C++"] = 5
team_size = 10

# %%
nx.draw(G,pos, with_labels=True)
nx.draw_networkx_nodes(G, pos, nodelist=skills, node_color = "red", node_size=1000, alpha=0.8)

# %%
# from pyvis.network import Network
# net = Network(notebook=True, height="1000px", width="100%", bgcolor="#222222", font_color="white")

# node_degree = dict(G.degree)

# nx.set_node_attributes(G, node_degree, 'size')

# net.from_nx(G)
# net.show("graph.html")

# %%
team = {}
team_experts = []
under_avg_students = []

# %%
for node in G.nodes(data=True):
    print(node)
# Out:
# ('Python', {'bipartite': 0, 'group': 3})
# ('Java', {'bipartite': 0, 'group': 1})
# ('C++', {'bipartite': 0, 'group': 0})
# ('Javascript', {'bipartite': 0, 'group': 1})
# ('SQL', {'bipartite': 0, 'group': 2})
# ('Alice', {'bipartite': 1, 'group': 3})
# ('Bob', {'bipartite': 1, 'group': 3})
# ('Charlie', {'bipartite': 1, 'group': 3})
# ('David', {'bipartite': 1, 'group': 3})
# ('Eve', {'bipartite': 1, 'group': 3})
# ('Frank', {'bipartite': 1, 'group': 3})
# ('Grace', {'bipartite': 1, 'group': 1})
# ('Hannah', {'bipartite': 1, 'group': 2})
# ('Ivan', {'bipartite': 1, 'group': 2})
# ('Judy', {'bipartite': 1, 'group': 2})
# ('Karl', {'bipartite': 1, 'group': 1})
# ('Lily', {'bipartite': 1, 'group': 1})
# ('Mike', {'bipartite': 1, 'group': 2})
# ('Nancy', {'bipartite': 1, 'group': 0})
# ('Oscar', {'bipartite': 1, 'group': 2})
# ('Peggy', {'bipartite': 1, 'group': 2})
# ('Quinn', {'bipartite': 1, 'group': 2})
# ('Ralph', {'bipartite': 1, 'group': 3})

# %%
domain_students = []
domain_students
# Out:
# []

# %%
for node in G.edges(data=True):
    if node[0] == "Python":
        for i in ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Ralph']:
            if i == node[1]:
                print(node[2]['weight'])
        # print(node[2]['weight'])
# Out:
# 0.5
# 0.4
# 0.3
# 0.2
# 0.1
# 0.5
# 0.5

# %%
nx.maximum_flow(G, "Python","Alice" , capacity='capacity')[1]["Python"]
# Out:
# {'Alice': 5.0,
#  'Bob': 6.0,
#  'Charlie': 7.0,
#  'David': 8.0,
#  'Eve': 9.0,
#  'Frank': 5.0,
#  'Oscar': 5.0,
#  'Ralph': 5.0}

# %%
nx.maximum_flow(G, "Python","Charlie" , capacity='capacity')[1]['Python']['Charlie']
# Out:
# 7.0

# %%
neighbors = ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Ralph']
for neighbor in neighbors:
    flow_value, flow_dict = nx.maximum_flow(G, neighbor,"Python" , capacity='capacity')
    print(flow_value,flow_value)
# Out:
# 50.0 50.0
# 50.0 50.0
# 50.0 50.0
# 50.0 50.0
# 50.0 50.0
# 50.0 50.0
# 50.0 50.0

# %%
[ G.edges for n in neighbors]
# Out:
# [EdgeView([('Python', 'Alice'), ('Python', 'Bob'), ('Python', 'Charlie'), ('Python', 'David'), ('Python', 'Eve'), ('Python', 'Frank'), ('Python', 'Oscar'), ('Python', 'Ralph'), ('Java', 'Alice'), ('Java', 'Bob'), ('Java', 'Charlie'), ('Java', 'David'), ('Java', 'Eve'), ('Java', 'Grace'), ('Java', 'Karl'), ('Java', 'Lily'), ('Java', 'Mike'), ('Java', 'Nancy'), ('Java', 'Quinn'), ('Java', 'Ralph'), ('C++', 'Alice'), ('C++', 'Bob'), ('C++', 'Charlie'), ('C++', 'Eve'), ('C++', 'Frank'), ('C++', 'Ivan'), ('C++', 'Karl'), ('C++', 'Lily'), ('C++', 'Mike'), ('C++', 'Nancy'), ('C++', 'Quinn'), ('C++', 'Ralph'), ('Javascript', 'Alice'), ('Javascript', 'Bob'), ('Javascript', 'Charlie'), ('Javascript', 'Eve'), ('Javascript', 'Grace'), ('Javascript', 'Judy'), ('Javascript', 'Karl'), ('Javascript', 'Lily'), ('Javascript', 'Mike'), ('Javascript', 'Peggy'), ('Javascript', 'Ralph'), ('SQL', 'Alice'), ('SQL', 'Bob'), ('SQL', 'Charlie'), ('SQL', 'Frank'), ('SQL', 'Hannah'), ('SQL', 'Karl'), ('SQL', 'Li
# ...

# %%
domain_students = []

# %%
project_complexity
# Out:
# {'Python': 2, 'Javascript': 2, 'SQL': 2, 'C++': 5}

# %%
    for language in project_complexity.keys():
        neighbors = [n for n in G.neighbors(language) if n not in domain_students]
        print(language, " : ", neighbors)
        weight_list = []
        for node in G.edges(data=True):
            if node[0] == language:
                for i in neighbors:
                    if i == node[1]:
                        weight_list.append(node[2]['weight'])

        avg_weight = sum(weight_list) / len(neighbors)
        print('weight list : ', weight_list)
        print('avg weight : ', avg_weight)

        temp_flow = {}
        for neighbor in neighbors:
            # print(neighbor," : ",G[node][neighbor]['weight'])
            flow_value = nx.maximum_flow(G, language, neighbor, capacity='capacity')[1][language][neighbor]
            # print("flow value = ",flow_value)
            # print("expected complexity = ",project_complexity[node])
            # print("collected skill = ",skill_levels[neighbor])

            temp_flow[neighbor] = flow_value
        print("team flow", temp_flow)

        # sG = G.subgraph(neighbors)
        # nx.draw(sG,pos, with_labels=True)

        under = [n for n in neighbors if G[language][n]['weight'] < avg_weight]
        print("Under avg : ", under)

        for i in under:
            del temp_flow[i]
        print("New temp_flow : ", temp_flow)
        domain_students = []

        conn = True
        sum_project_complexity = 0
        while conn:
            print("came to while loop")
            print("domain_students : ", domain_students)
            if len(domain_students) > 0:
                # print("domain students : ",[temp_flow[domain_student] for domain_student in domain_students])
                for domain_student in domain_students:
                    if domain_student in temp_flow_keys:
                        if len(temp_flow) > 1 and (domain_student in temp_flow.keys()):
                            del temp_flow[domain_student]
                            print("del : ", domain_student)
            temp_flow_keys = list(temp_flow.keys())
            temp_flow_values = list(temp_flow.values())

            print("temp_flow_keys : ", temp_flow_keys)
            print("temp_flow_values : ", temp_flow_values)

            max_flow = max(temp_flow_values)
            print("max-flow : ", max_flow)
            max_persons = [i for i in temp_flow_keys if temp_flow[i] == max(temp_flow_values)]
            print("max-person : ", max_persons)

            # if len(temp_flow) > 1:
            #     if G[node][temp_flow[max_flow]]['weight'] > avg_weight:
            #         print("student : ",temp_flow[max(temp_flow_keys)])
            #         break
            #     else:
            #         # print("remove : ",temp_flow[max_flow]," : ",max_flow," : ",G[node][temp_flow[max_flow]]['weight']," : ",avg_weight)
            #         del temp_flow[max_flow]
            # print("max-flow : ",temp_flow)
            # print("student : ",temp_flow[max(temp_flow.keys())])

            if len(domain_students) > 0:
                for domain_student in domain_students:
                    sum_project_complexity += skill_levels[domain_student][language]
            else:
                sum_project_complexity = 0

            if len(max_persons) > 1:
                sum_persons = 0
                # for max_person in max_persons:
                #     if max_person not in domain_students:
                #         domain_students.append(max_person)
                #         sum_persons += skill_levels[max_person][language]
                sum_project_complexity += skill_levels[max_persons[0]][language]
                domain_students.append(max_persons[0])
            else:
                # print(max_persons[0])
                sum_project_complexity += skill_levels[max_persons[0]][language]
                domain_students.append(max_persons[0])

            print("sum_project_complexity : ", sum_project_complexity)
            print("requested complexity : ", project_complexity[language])
            if sum_project_complexity < project_complexity[language]:
                conn = True
            else:
                conn = False

        team[language] = domain_students

    print(team)
# Out:
# Python  :  ['Alice', 'Bob', 'Charlie', 'David', 'Oscar', 'Ralph']
# weight list :  [0.5, 0.4, 0.3, 0.2, 0.5, 0.5]
# avg weight :  0.39999999999999997
# team flow {'Alice': 5.0, 'Bob': 6.0, 'Charlie': 7.0, 'David': 8.0, 'Oscar': 5.0, 'Ralph': 5.0}
# Under avg :  ['Charlie', 'David']
# New temp_flow :  {'Alice': 5.0, 'Bob': 6.0, 'Oscar': 5.0, 'Ralph': 5.0}
# came to while loop
# domain_students :  []
# temp_flow_keys :  ['Alice', 'Bob', 'Oscar', 'Ralph']
# temp_flow_values :  [5.0, 6.0, 5.0, 5.0]
# max-flow :  6.0
# max-person :  ['Bob']
# sum_project_complexity :  4
# requested complexity :  2
# Javascript  :  ['Alice', 'Charlie', 'Eve', 'Grace', 'Judy', 'Karl', 'Lily', 'Mike', 'Peggy', 'Ralph']
# weight list :  [0.2, 0.5, 0.3, 0.4, 0.5, 0.3, 0.2, 0.3, 0.5, 0.2]
# avg weight :  0.33999999999999997
# team flow {'Alice': 8.0, 'Charlie': 5.0, 'Eve': 7.0, 'Grace': 6.0, 'Judy': 5.0, 'Karl': 7.0, 'Lily': 8.0, 'Mike': 7.0, 'Peggy': 5.0, 'Ralph': 8.0}
# ...

# %%
team
# Out:
# {'Python': ['Bob'],
#  'Javascript': ['Grace'],
#  'SQL': ['Charlie'],
#  'C++': ['Eve', 'Frank']}

# %%
team_experts
# Out:
# ['Bob', 'Charlie', 'Mike', 'Eve', 'Karl']

# %%
alltogether_team = []
for k,v in team.items():
    alltogether_team += v

# %%
alltogether_team
# Out:
# ['Bob', 'Grace', 'Charlie', 'Eve', 'Frank']

# %%
close_centrality = nx.closeness_centrality(G)
close_centrality
# Out:
# {'Python': 0.4888888888888889,
#  'Java': 0.6111111111111112,
#  'C++': 0.6285714285714286,
#  'Javascript': 0.6470588235294118,
#  'SQL': 0.6470588235294118,
#  'Alice': 0.6666666666666666,
#  'Bob': 0.5789473684210527,
#  'Charlie': 0.5789473684210527,
#  'David': 0.4888888888888889,
#  'Eve': 0.55,
#  'Frank': 0.5238095238095238,
#  'Grace': 0.4782608695652174,
#  'Hannah': 0.4583333333333333,
#  'Ivan': 0.46808510638297873,
#  'Judy': 0.55,
#  'Karl': 0.55,
#  'Lily': 0.5641025641025641,
#  'Mike': 0.55,
#  'Nancy': 0.5,
#  'Oscar': 0.5,
#  'Peggy': 0.4888888888888889,
#  'Quinn': 0.5116279069767442,
#  'Ralph': 0.5789473684210527}

# %%
import pandas as pd
closeness_df = pd.DataFrame.from_dict(close_centrality, orient='index', columns=['closeness'])
closeness_df.drop(skills, inplace=True)
closeness_df.sort_values(by=['closeness'], ascending=False,inplace=True)

# %%
closeness_df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
closeness_df.head()
# Out:
#          closeness
# Alice     0.666667
# Bob       0.578947
# Ralph     0.578947
# Charlie   0.578947
# Lily      0.564103

# %%
messure = {}
for name in alltogether_team:
    l = closeness_df.index == name
    for i in range(len(l)):
        if l[i]:

            messure[name] = closeness_df.iloc[i,0]

# %%
messure
# Out:
# {'Bob': 0.5789473684210527,
#  'Grace': 0.4782608695652174,
#  'Charlie': 0.5789473684210527,
#  'Eve': 0.55,
#  'Frank': 0.5238095238095238}

# %%
val = list(messure.values())
val.sort(reverse=True)
print(val)
# Out:
# [0.5789473684210527, 0.5789473684210527, 0.55, 0.5238095238095238, 0.4782608695652174]

# %%
team_experts = [k for k,v in messure.items() if v in val[:3]]

# %%
team_experts
# Out:
# ['Bob', 'Charlie', 'Eve']

# %%
for i in ['Mike', 'Frank', 'Oscar']:
    print(skill_levels[i])
# Out:
# {'SQL': 4, 'Javascript': 3, 'C++': 2, 'Java': 1}
# {'Python': 5, 'C++': 4, 'SQL': 3}
# {'Python': 5, 'SQL': 4}
